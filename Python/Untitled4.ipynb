# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r"C:\Users\kkisho15\Documents\check1.csv")

# %%
df= df.replace(0,'nan')
df=df.dropna(how='all',axis=0)

# %%
df
# Out:
#   column 1  value
# 0         a   nan
# 1         s     1
# 2         d     2
# 3         f   nan
# 4         g     3
# 5         h     4
# 6         j     5

# %%
df=df.dropna()

# %%
df
# Out:
#   column 1  value
# 0         a   nan
# 1         s     1
# 2         d     2
# 3         f   nan
# 4         g     3
# 5         h     4
# 6         j     5

# %%
# !pip install scrapy

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (2.21.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests) (2018.11.29)

# %%
# !pip install html5lib
# Out:
# Requirement already satisfied: html5lib in c:\programdata\anaconda3\lib\site-packages (1.0.1)
# Requirement already satisfied: six>=1.9 in c:\programdata\anaconda3\lib\site-packages (from html5lib) (1.12.0)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\lib\site-packages (from html5lib) (0.5.1)

# %%
# !pip install bs4

# %%
import requests 
URL = "https://www.geeksforgeeks.org/data-structures/"
r = requests.get(URL) 
print(r.content)
# Out:
# b'<!DOCTYPE html>\r\n<!--[if IE 7]>\r\n<html class="ie ie7" lang="en-US" prefix="og: http://ogp.me/ns#">\r\n<![endif]-->\r\n<!--[if IE 8]>\r\n<html class="ie ie8" lang="en-US" prefix="og: http://ogp.me/ns#">\r\n<![endif]-->\r\n<!--[if !(IE 7) | !(IE 8)  ]><!-->\r\n<html lang="en-US" prefix="og: http://ogp.me/ns#" >\r\n\r\n<!--<![endif]-->\r\n<head>\r\n<meta charset="UTF-8" />\r\n<meta name="viewport" content="width=device-width" />\r\n<meta name="description" content="A Computer Science portal for geeks. It contains well written, well thought and well explained computer science and programming articles, quizzes and practice/competitive programming/company interview Questions.">\r\n<link rel="shortcut icon" href="https://www.geeksforgeeks.org/favicon.ico" type="image/x-icon" />\r\n\r\n<meta name="theme-color" content="#0f9d58" />\r\n\r\n<meta property="og:image" content="https://www.geeksforgeeks.org/wp-content/uploads/gfg_200X200.png">\r\n<meta property="og:image:type" content="image/png">\r\n<meta property="og:image:width" content="200">\r\n<meta property="og:image:height" content="200">\r\n<script src="//cdnjs.cloudflare.com/ajax/libs/require.js/2.1.14/require.min.js"></script>\r\n\r\n<title>Data Structures - GeeksforGeeks</title>\r\n<link rel="profile" href="http://gmpg.org/xfn/11" />\r\n<link rel="pingback" href="" />\r\n<!--[if lt IE 9]>\r\n<script src="https://www.geeksforgeeks.org/wp-content/themes/iconic-one/js/html5.js" type="text/javascript"></script>\r\n<![endif]-->\r\n\r\n<script type="application/ld+json">\r\n    {\r\n        "@context" : "http://schema.org",\r\n        "@type" : "Organization",\r\n        "name" : "GeeksforGeeks",\r\n        "url" : "https://www.geeksforgeeks.org/",\r\n        "logo" : "https://www.geeksforgeeks.org/gfgLogo.png",\r\n        "description" : "A computer science portal for geeks. It contains well written, well thought and well explained computer science and programming articles, quizzes and practice/competitive programming/company interview Questions.",\r\n        "founder": [\r\n            {\r\n                "@type" : "Person",\r\n                "name" : "Sandeep Jain",\r\n                "url" : "https://in.linkedin.com/in/sandeep-jain-b3940815"\r\n            }\r\n        ],\r\n        "sameAs" : [ "https://www.facebook.com/geeksforgeeks.org/",\r\n            "https://twitter.com/geeksforgeeks",\r\n            "https://www.linkedin.com/company/1299009",\r\n            "https://www.youtube.com/geeksforgeeksvideos/"\r\n        ]\r\n    }\r\n</script>\r\n<script>\r\n\r\n    var arrPostCat = new Array();\r\n        var tIds = "";\r\n    var domain = 1;\r\n    var arrPost = new Array();\r\n    var post_id = "125686";\r\n    var post_type = "page";\r\n    var post_slug = window.location.href;\r\n    var ip = "13.228.69.166";\r\n    var post_title = "Data Structures";\r\n    var post_status = "publish";\r\n    var post_date = "2014-02-01 20:16:50";\r\n                            var isAdminLoggedIn = 0;\r\n        </script>\r\n\n<!-- This site is optimized with the Yoast SEO plugin v7.6 - https://yoast.com/wordpress/plugins/seo/ -->\n<meta name="description" content="Complete list of Data Structure, Practice Problems, Quizzes, Array, Linked List, Stack, Queue, Trees, Heap, Graph, Matrix, Advanced Data Structures"/>\n<link rel="canonical" href="https://www.geeksforgeeks.org/data-structures/" />\n<meta property="og:locale" content="en_US" />\n<meta property="og:type" content="article" />\n<meta property="og:title" content="Data Structures - GeeksforGeeks" />\n<meta property="og:description" content="Complete list of Data Structure, Practice Problems, Quizzes, Array, Linked List, Stack, Queue, Trees, Heap, Graph, Matrix, Advanced Data Structures" />\n<meta property="og:url" content="https://www.geeksforgeeks.org/data-structures/" />\n<meta property="og:site_name" content="GeeksforGeeks" />\n<script type=\'application/ld+json\'>{"@context":"https:\\/\\/schema.org","@type":"Organization" ...

# %%
import requests 
from bs4 import BeautifulSoup 
  
URL = "http://www.values.com/inspirational-quotes"
r = requests.get(URL) 
  
soup = BeautifulSoup(r.content, 'html5lib') 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <link href="https://fonts.googleapis.com/css?family=Roboto:900|Lato:300,400,400italic,600,700|Raleway:300,400,500,600,700|Crete+Round:400italic|Zilla+Slab" rel="stylesheet" type="text/css"/>
#   <link href="/assets/application-c1a6c51b1b6ff15dacede3f5054ae3ce.css" media="all" rel="stylesheet"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <!--[if lt IE 9]><script src="http://css3-mediaqueries-js.googlecode.com/svn/trunk/css3-mediaqueries.js"></script><![endif]-->
#   <title>
#    Inspirational Quotes - Motivational Quotes - Leadership Quotes | PassItOn.com
#   </title>
#   <meta content="Find the perfect quotation from our hand-picked collection of inspiring quotes by hundreds of authors." name="description"/>
#   <meta content="authenticity_token" name="csrf-param"/>
#   <meta content="6L3oG/xliT+BNsBzaBVIuCrZ/ZRZE0BjcSJ7xspFojxWJtyQakLmleKab17/Ab0c8beq+YiIKxtmuV2ojPegXQ==" name="csrf-token"/>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#         })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#         ga('create', 'UA-1179606-29', 'auto');
#         ga('require', 'displayfeatures');
#         ga('send', 'pageview');
#   </script>
#   <script>
#    window.fbAsyncInit = function() {
#         FB.init({
#           appId      : '483774921971842',
#           cookie     : true,
#           xfbml      : true,
#           version    : '3.0'
#         });
#
#         FB.AppEvents.logPageView();
#
#       };
#
#       (function(d, s, id){
#          var js, fjs = d.getElementsByTagName(s)[0];
#          if (d.getElementById(id)) {return;}
#          js = d.createElement(s); js.id = id;
#          js.src = "https://connect.facebook.net/en_US/sdk.js";
#          fjs.parentNode.insertBefore(js, fjs);
#        }(document, 'script', 'facebook-jssdk'));
#   </script>
#   <meta content="passiton.com" property="og:site_name"/>
#   <meta content="Inspirational Quotes - Motivational Quotes - Leadership Quotes" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://www.passiton.com/passiton.jpg" property="og:image"/>
#   <meta content="https://www.passiton.com/inspirational-quotes" property="og:url"/>
#   <meta content="Find the perfect quotation from our hand-picked collection of inspiring quotes by hundreds of authors." property="og:description"/>
#   <meta content="483774921971842" property="fb:app_id"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@passiton" name="twitter:site"/>
#   <meta content="@passiton" name="twitter:creator"/>
#   <meta content="Inspirational Quotes - Motivational Quotes - Leadership Quotes" name="twitter:title"/>
#   <meta content="Find the perfect quotation from our hand-picked collection of inspiring quotes by hundreds of authors." name="twitter:description"/>
#   <meta content="https://www.passiton.com/passiton.jpg" name="twitter:image"/>
#   <meta content="https://www.passiton.com/inspirational-quotes" name="twitter:url"/>
#   <meta content="passiton.com" itemprop="name"/>
#   <meta content="Find the perfect quotation from our hand-picked collection of inspiring quotes by hundreds of authors." itemprop="description"/>
#   <meta content="https://www.passiton.com/passiton.jpg" itemprop="image"/>
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link color="#C8102E" href="/passiton_arrow.svg" rel="mask-icon"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <link color="#5bbad5" href="/safari-pinned-tab.svg" rel="mask-icon"/>
#   <meta content="passiton" name="apple-mobile-web-app-title"/>
#   <meta content="passiton" name="application-name"/>
#   <meta content="#f1f1f1" name="theme-color"/>
#  </head>
#  <body class="stretched no-transition quotes_index">
#   <div class="clearfix" id="wrapper">
#    <header class="full-header dark" data-sticky-class="dark" id="header">
#     <div id="header-wrap">
#      <div class="container clearfix">
#       <div id="primary-menu-trigger">
#        <i class="icon-reorder">
#        </i>
#       </div>
#       <div id="logo">
#        <a class="standard-logo" data-dark-logo="/assets/logo-dark-c47a5f31c5be3b9f75a45035dc5035d2.png" href="/">
#         <img alt="passiton.com" src="/assets/logo-c47a5f31c5be3b9f75a45035dc5035d2.png"/>
#        </a>
#        <a class="retina-logo" data-dark-logo="/assets/logo-dark@2x-0ec50d119efb5420f2d9af0b6f33fb59.png" href="/">
#         <img alt="passiton.com" src="/assets/logo@2x-0ec50d119efb5420f2d9af0b6f33fb59.png"/>
#        </a>
#       </div>
#       <nav class="" id="primary-menu">
#        <ul>
#         <li class="current">
#          <a href="/inspirational-quotes">
#           quotes
#          </a>
#         </li>
#         <li class="">
#          <a href="/inspirational-stories-tv-spots">
#           videos
#          </a>
#         </li>
#         <li class="">
#          <a href="/inspirational-sayings-billboards">
#           <i class="icon-caret-down">
#           </i>
#           billboards
#          </a>
#          <ul>
#           <li class="">
#            <a href="/inspirational-sayings-billboards">
#             official billboards
#            </a>
#           </li>
#           <li class="">
#            <a href="/your-billboards/create">
#             create your own billboard
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="">
#          <a href="/radio">
#           radio ads
#          </a>
#         </li>
#         <li class="">
#          <a href="/who-we-are">
#           about us
#          </a>
#         </li>
#         <li class="">
#          <a href="/contact-us">
#           contact
#          </a>
#         </li>
#         <li class="">
#          <a class="dropdown-toggle" href="">
#           <i class="icon-caret-down">
#           </i>
#           language
#          </a>
#          <ul class="dark">
#           <li class="dark">
#            <a href="https://www.pasala.org/" target="_blank">
#             Español
#            </a>
#           </li>
#           <li class="dark">
#            <a href="https://www.umavidamelhor.org/" target="_blank">
#             Português
#            </a>
#           </li>
#           <li class="dark">
#            <a href="https://values.cn.com/" target="_blank">
#             中文
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#        <div id="top-search">
#         <a href="#" id="top-search-trigger">
#          <i class="icon-search3">
#          </i>
#          <i class="icon-line-cross">
#          </i>
#         </a>
#         <form action="/search" method="get">
#          <input class="form-control" name="q" placeholder="search" type="text" value=""/>
#         </form>
#        </div>
#       </nav>
#      </div>
#     </div>
#    </header>
#    <section id="content">
#     <div class="content-wrap">
#      <div class="container clearfix">
#       <div class="center_wrapper">
#        <div class="row">
#         <div class="col-sm-12">
#          <div class="inbox_inspiration text-left">
#           <div class="row">
#            <div class="col-sm-4">
#             <h5>
#              Subscribe to our FREE
#              <br/>
#              inspirational quote emails!
#             </h5>
#             <form accept-charset="UTF-8" action="/users" class="simple_form new_user" id="new_user" method="post" novalidate="novalidate">
#              <input name="utf8" type="hidden" value="✓"/>
#              <input name="authenticity_token" type="hidden" value="7NhlC1hdpSci13goyFmsyleTSjaZZHgc7Mx69XFVYVFSQ1GAznrKjUF71wVfTVlujP0dW0j/E2T7V1ybN+djMA=="/>
#              <div class="row">
#               <div class="col-sm-8">
#                <div class="input email optional user_email">
#                 <input class="string email optional sm-form-control sm-form-control-grey" id="user_email" name="user[email]" placeholder="Type your email address" style="height: 32px;" type="email"/>
#                </div>
#               </div>
#               <div class="col-sm-4">
#                <input class="btn btn btn-default btn-red noradius btn-hero" data-disable-with="Sending..." name="commit" type="submit" value="Subscribe"/>
#               </div>
#              </div>
#             </form>
#            </div>
#            <div class="col-sm-8">
#             <div class="row">
#              <div class="col-sm-4 bumper">
#               <div class="cycle-slideshow" data-cycle-fx="flipHorz" data-cycle-timeout="7000">
#                <img alt="20170116 monday quote" class="img-responsive" src="https://quotes.values.com/quote_artwork/3763/medium/20170116_monday_quote.jpg"/>
#                <img alt="Friday quote" class="img-responsive" src="https://quotes.values.com/quote_artwork/7347/medium/friday_quote.jpg"/>
#                <img alt="20170303 friday quote" class="img-responsive" src="https://quotes.values.com/quote_artwork/5014/medium/20170303_friday_quote.jpg"/>
#               </div>
#              </div>
#              <div class="col-sm-4 bumper">
#               <div class="cycle-slideshow" data-cycle-fx="flipHorz" data-cycle-timeout="6800">
#                <img alt="20161213 tuesday quote new" class="img-responsive" src="https://quotes.values.com/quote_artwork/7579/medium/20161213_tuesday_quote_new.jpg"/>
#                <img alt="Monday quote" class="img-responsive" src="https://quotes.values.com/quote_artwork/7313/medium/monday_quote.jpg"/>
#                <img alt="Friday quote" class="img-responsive" src="https://quotes.values.com/quote_artwork/7302/medium/friday_quote.jpg"/>
#               </div>
#              </div>
#              <div class="col-sm-4 bumper">
#               <div class="cycle-slideshow" data-cycle-fx="flipHorz" data-cycle-timeout="6600">
#                <img alt="20160906 tuesday quote" class="img-responsive" src="https://quotes.values.com/quote_artwork/6741/medium/20160906_tuesday_quote.jpg"/>
#                <img alt="Wednesday quote" class="img-responsive" src="https://quotes.values.com/quote_artwork/7280/medium/wednesday_quote.jpg"/>
#                <img alt="Tuesday quote" class="img-responsive" src="https://quotes.values.com/quote_artwork/7279/medium/tuesday_quote.jpg"/>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="row">
#         <div class="col-sm-6 col-sm-offset-3">
#          <form action="/inspirational-quotes" class="nobottommargin" id="" method="get" role="form">
#           <div class="input-group divcenter">
#            <input class="form-control" name="q" placeholder="Search quotes..." type="text"/>
#            <span class="input-group-btn">
#             <button class="btn btn-default" type="submit">
#              search
#             </button>
#            </span>
#           </div>
#          </form>
#          <hr/>
#         </div>
#        </div>
#       </div>
#       <div class="clear">
#       </div>
#       <div class="portfolio grid-container portfolio-4 portfolio-masonry clearfix" id="portfolio">
#        <article class="portfolio-item quotation hard work">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/7893-success-isnt-always-about-greatness-its-about">
#           <img alt="Success isn't always about greatness. It's about consistency. Consistent hard work leads to success. Greatness will come. #&lt;Author:0x00007f5cf42a1518&gt;" class="hover" src="https://quotes.values.com/quote_artwork/7893/medium/20190403_wednesday_quote.jpg?1553889106"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation hard work">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/7892-successful-people-are-not-gifted-they-just">
#           <img alt="Successful people are not gifted; they just work hard, then succeed on purpose. #&lt;Author:0x00007f5cf42b65a8&gt;" class="hover" src="https://quotes.values.com/quote_artwork/7892/medium/20190402_tuesday_quote.jpg?1553889075"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation hard work">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/6432-i-know-the-price-of-success-dedication-hard">
#           <img alt="I know the price of success: dedication, hard work, and an unremitting devotion to the things you want to see happen.  #&lt;Author:0x00007f5cf42d2cf8&gt;" class="hover" src="https://quotes.values.com/quote_artwork/6432/medium/20190401_monday_quote.jpg?1553888798"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation caring">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/7890-taking-care-of-yourself-doesnt-mean-me-first">
#           <img alt="Taking care of yourself doesn't mean me first, it means me too. #&lt;Author:0x00007f5cf42ec950&gt;" class="hover" src="https://quotes.values.com/quote_artwork/7890/medium/20190329_friday_quote.jpg?1553276143"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation caring">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/7891-a-kind-word-is-like-a-spring-day">
#           <img alt="A kind word is like a spring day. #&lt;Author:0x00007f5cf4307480&gt;" class="hover" src="https://quotes.values.com/quote_artwork/7891/medium/20190328_thursday_quote_alternate.jpg?1553534100"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation caring">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/7888-my-mission-in-life-is-to-be-kind">
#           <img alt="My mission in life is to be kind, compassionate, caring, and loving in order to find and feel the deepest joy of life. #&lt;Author:0x00007f5cf4314428&gt;" class="hover" src="https://quotes.values.com/quote_artwork/7888/medium/20190327_wednesday_quote.jpg?1553276090"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation caring">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/3203-i-feel-the-capacity-to-care-is-the-thing-which">
#           <img alt="I feel the capacity to care is the thing which gives life its deepest significance. #&lt;Author:0x00007f5cf43bbe08&gt;" class="hover" src="https://quotes.values.com/quote_artwork/3203/medium/20190326_tuesday_quote.jpg?1553276065"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation caring">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/7887-never-believe-that-a-few-caring-people-can-t">
#           <img alt="Never believe that a few caring people can’t change the world. For, indeed, that’s all who ever have. #&lt;Author:0x00007f5cf43c9878&gt;" class="hover" src="https://quotes.values.com/quote_artwork/7887/medium/20190325_monday_quote.jpg?1553276034"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation spread your wings">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/7886-don-t-be-afraid-to-expand-yourself-to-step-out">
#           <img alt="Don’t be afraid to expand yourself, to step out of your comfort zone. That’s where the joy and the adventure lie. #&lt;Author:0x00007f5cf43e2990&gt;" class="hover" src="https://quotes.values.com/quote_artwork/7886/medium/20190322_friday_quote.jpg?1552683104"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation spread your wings">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/7359-at-times-you-have-to-leave-the-city-of-your">
#           <img alt="At times you have to leave the city of your comfort and go into the wilderness of your intuition. What you'll discover will be wonderful. What you'll discover is yourself. #&lt;Author:0x00007f5cf43f1dc8&gt;" class="hover" src="https://quotes.values.com/quote_artwork/7359/medium/20190321_thursday_quote.jpg?1552683072"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation spread your wings">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/7885-for-what-it-s-worth-it-s-never-too-late-or-in">
#           <img alt="For what it’s worth: it’s never too late or, in my case, too early to be whoever you want to be. #&lt;Author:0x00007f5cf44004b8&gt;" class="hover" src="https://quotes.values.com/quote_artwork/7885/medium/20190320_wednesday_quote_alternate2.jpg?1552689922"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation spread your wings">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/4171-twenty-years-from-now-you-will-be-more">
#           <img alt="Twenty years from now you will be more disappointed by the things you didn't do than by the ones you did. So throw off the bowlines. Sail away from the safe harbor. Catch the trade winds in your sails. Explore. Dream. Discover. #&lt;Author:0x00007f5cf4414968&gt;" class="hover" src="https://quotes.values.com/quote_artwork/4171/medium/20190319_tuesday_quote.jpg?1552682997"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation spread your wings">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/7884-embrace-uncertainty-some-of-the-most-beautiful">
#           <img alt="Embrace uncertainty. Some of the most beautiful chapters in our lives won’t have a title until much later. #&lt;Author:0x00007f5cf4447ae8&gt;" class="hover" src="https://quotes.values.com/quote_artwork/7884/medium/20190318_monday_quote.jpg?1552682962"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation listening">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/6664-the-most-important-thing-in-communication-is-to">
#           <img alt="The most important thing in communication is to hear what isn't being said. #&lt;Author:0x00007f5cf4454a68&gt;" class="hover" src="https://quotes.values.com/quote_artwork/6664/medium/20190315_friday_quote.jpg?1552095946"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation listening">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/7883-deep-listening-is-the-kind-of-listening-that">
#           <img alt="Deep listening is the kind of listening that can help relieve the suffering of another person... You listen with only one purpose: to help him or her to empty their heart.  #&lt;Author:0x00007f5cf40d61e8&gt;" class="hover" src="https://quotes.values.com/quote_artwork/7883/medium/20190314_thursday_quote_updated.jpg?1552576582"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation listening">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/7882-theres-a-lot-of-difference-between-listening">
#           <img alt="There's a lot of difference between listening and hearing. #&lt;Author:0x00007f5cf44ab598&gt;" class="hover" src="https://quotes.values.com/quote_artwork/7882/medium/20190313_wednesday_quote.jpg?1552095885"/>
#          </a>
#         </div>
#        </article>
#       </div>
#      </div>
#     </div>
#     <div class="center_wrapper">
#      <div class="pagination-centered" id="infinite-scrolling">
#       <ul class="pagination">
#        <li class="prev previous_page unavailable">
#         <a href="#">
#          «
#         </a>
#        </li>
#        <li class="current">
#         <a href="/inspirational-quotes?page=1">
#          1
#         </a>
#        </li>
#        <li>
#         <a href="/inspirational-quotes?page=2" rel="next">
#          2
#         </a>
#        </li>
#        <li>
#         <a href="/inspirational-quotes?page=3">
#          3
#         </a>
#        </li>
#        <li>
#         <a href="/inspirational-quotes?page=4">
#          4
#         </a>
#        </li>
#        <li>
#         <a href="/inspirational-quotes?page=5">
#          5
#         </a>
#        </li>
#        <li class="unavailable">
#         <a href="#">
#          <span class="gap">
#           …
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="/inspirational-quotes?page=224">
#          224
#         </a>
#        </li>
#        <li class="next next_page ">
#         <a href="/inspirational-quotes?page=2" rel="next">
#          »
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </section>
#    <footer class="dark" id="footer">
#     <div class="container clearfix">
#      <div class="row">
#       <div class="col-sm-3">
#        <ul class="footer_nav_links">
#         <li>
#          <a href="/inspirational-quotes">
#           Inspirational Quotations
#          </a>
#         </li>
#         <li>
#          <a href="/inspirational-stories-tv-spots">
#           Pass It On Videos
#          </a>
#         </li>
#         <li>
#          <a href="/inspirational-sayings-billboards">
#           Billboards
#          </a>
#         </li>
#         <li>
#          <a href="/radio">
#           Radio Ads
#          </a>
#         </li>
#         <li>
#          <a href="/inspirational-audio-stories">
#           Podcasts
#          </a>
#         </li>
#         <li>
#          <a href="/pass-it-on-ecards">
#           Ecards
#          </a>
#         </li>
#         <li>
#          <a href="/pass-it-on-downloads">
#           Downloads
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-sm-3">
#        <ul class="footer_nav_links">
#         <li>
#          <a href="/your-inspirational-stories">
#           Your Value Stories
#          </a>
#         </li>
#         <li>
#          <a href="/your-inspirational-stories/submit">
#           What Value Defines You?
#          </a>
#         </li>
#         <li>
#          <a href="/your-everyday-heroes">
#           Your Hero Stories
#          </a>
#         </li>
#         <li>
#          <a href="/your-everyday-heroes/submit">
#           Tell Us About Your Hero
#          </a>
#         </li>
#         <li>
#          <a href="/your-billboards">
#           Create Your Own Billboard
#          </a>
#         </li>
#         <li>
#          <a href="/users/subscribe">
#           Subscribe to Daily Quotes
#          </a>
#         </li>
#         <li>
#          <a href="/poster-requests/new">
#           Free Posters &amp; DVD for Schools
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-sm-3">
#        <ul class="footer_nav_links">
#         <li>
#          <a href="/who-we-are">
#           About Us
#          </a>
#         </li>
#         <li>
#          <a href="/who-we-are#faqs">
#           FAQs
#          </a>
#         </li>
#         <li>
#          <a href="/contact-us">
#           Contact Us
#          </a>
#         </li>
#         <li>
#          <a href="/who-we-are#awards">
#           Foundation Recognition
#          </a>
#         </li>
#         <li>
#          <a href="/who-we-are#media">
#           For Media Companies
#          </a>
#         </li>
#         <li>
#          <a href="/terms-of-use">
#           Terms of Use
#          </a>
#          &amp;
#          <a href="/privacy-policy">
#           Privacy Policy
#          </a>
#         </li>
#         <li style="color: #1a1a1a;">
#          en
#         </li>
#        </ul>
#        <div class="clearfix">
#        </div>
#       </div>
#       <div class="col-sm-3">
#        <a href="/">
#         <img alt="Passiton footer logo" height="26" src="/assets/passiton_footer_logo-65160d9e467efbfd864f084606eacd68.png" style="margin-bottom: 20px;" width="200"/>
#        </a>
#        <br/>
#        <ul class="passiton-share-icons">
#         <li>
#          <a class="social-icon si-small si-rounded si-facebook" href="https://www.facebook.com/valuescom">
#           <i class="icon-facebook">
#           </i>
#          </a>
#         </li>
#         <li>
#          <a class="social-icon si-small si-rounded si-twitter" href="https://twitter.com/passiton_values">
#           <i class="icon-twitter">
#           </i>
#          </a>
#         </li>
#         <li>
#          <a class="social-icon si-small si-rounded si-instagram" href="https://www.instagram.com/passiton_values/">
#           <i class="icon-instagram">
#           </i>
#          </a>
#         </li>
#         <li>
#          <a class="social-icon si-small si-rounded si-youtube" href="https://www.youtube.com/c/passiton_values">
#           <i class="icon-youtube-play">
#           </i>
#          </a>
#         </li>
#         <li>
#          <a class="social-icon si-small si-rounded si-pinterest" href="https://www.pinterest.com/passiton_values/">
#           <i class="icon-pinterest">
#           </i>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </footer>
#   </div>
#   <div class="icon-angle-up" id="gotoTop">
#   </div>
#   <script src="/assets/application-584ea9ac57db67909afca88e1ad6568a.js">
#   </script>
#   <script integrity="sha384-EwBObn5QAxP8f09iemwAJljc+sU+eUXeL9vSBw1eNmVarwhKk2F9vBEpaN9rsrtp" src="//instant.page/1.1.0" type="module">
#   </script>
#  </body>
# </html>

# %%
import requests 
from bs4 import BeautifulSoup 
import csv 
  
URL = "http://www.values.com/inspirational-quotes"
r = requests.get(URL) 
  
soup = BeautifulSoup(r.content, 'html5lib') 
  
quotes=[]  # a list to store quotes 
  
table = soup.find('div', attrs = {'id':'container'}) 
  
for row in table.find.All('div', attrs = {'class':'quote'}): 
    quote = {} 
    quote['theme'] = row.h5.text 
    quote['url'] = row.a['href'] 
    quote['img'] = row.img['src'] 
    quote['lines'] = row.h6.text 
    quote['author'] = row.p.text 
    quotes.append(quote) 
  
filename = 'inspirational_quotes.csv'
with open(filename, 'wb') as f: 
    w = csv.DictWriter(f,['theme','url','img','lines','author']) 
    w.writeheader() 
    for quote in quotes: 
        w.writerow(quote)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-4c7e6a1a8317> in <module>
#      13 table = soup.find('div', attrs = {'id':'container'})
#      14
# ---> 15 for row in table.find.All('div', attrs = {'class':'quote'}):
#      16     quote = {}
#      17     quote['theme'] = row.h5.text
#
# AttributeError: 'NoneType' object has no attribute 'find'
